# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generating sample data to test TSM implementation

#np.random.seed(139)
x, y, z = np.random.random((3, 10))

fig, ax = plt.subplots()
scat = ax.scatter(x, y, c=z, s=100)
ax.margins(0.05)

# %%
#TODO: Implement TSM, consider an implementation relying on roads / transportation
#TODO: Fetch from API list of all institutions to visit
#TODO: Apply TSM to list of institutions
